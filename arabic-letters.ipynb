# %% [markdown]
# <a href="https://www.kaggle.com/code/yasinsoylu123/arabic-letters?scriptVersionId=116446788" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import Image, display
import random
import math
import tensorflow as tf
from keras.preprocessing.image import load_img,img_to_array,ImageDataGenerator
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.utils import plot_model 
from tensorflow.keras.layers import Input, Dense, Dropout, Flatten, Activation,Concatenate
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.utils import to_categorical 
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras import backend, models
from sklearn.metrics import confusion_matrix
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from tensorflow.keras.applications import VGG16, MobileNet
from keras.applications.vgg16 import preprocess_input

# %%
arabic_characters = ['alef', 'beh', 'teh', 'theh', 'jeem', 'hah', 'khah', 'dal', 'thal',
                    'reh', 'zain', 'seen', 'sheen', 'sad', 'dad', 'tah', 'zah', 'ain',
                    'ghain', 'feh', 'qaf', 'kaf', 'lam', 'meem', 'noon', 'heh', 'waw', 'yeh']

# %%
x_train = pd.read_csv("/kaggle/input/ahcd1/csvTrainImages 13440x1024.csv",header=None).to_numpy()
y_train = pd.read_csv("/kaggle/input/ahcd1/csvTrainLabel 13440x1.csv",header=None).to_numpy()-1 

x_test = pd.read_csv("/kaggle/input/ahcd1/csvTestImages 3360x1024.csv",header=None).to_numpy()
y_test = pd.read_csv("/kaggle/input/ahcd1/csvTestLabel 3360x1.csv",header=None).to_numpy()-1

print("x_train.shape =", x_train.shape, "\ny_train.shape =", y_train.shape, "\nx_test.shape =", x_test.shape, "\ny_test.shape =", y_test.shape)
# Out:
# x_train.shape = (13440, 1024)
# y_train.shape = (13440, 1)
# x_test.shape = (3360, 1024)
# y_test.shape = (3360, 1)

# %%
shape=(32,32,1)

# %%
x_train = x_train.reshape(-1,32,32,1)
x_test = x_test.reshape(-1,32,32,1)

x_train = x_train / 255.0
x_test = x_test / 255.0

print(x_train.shape, x_test.shape)

ra = np.random.randint(0, 13440, size=25)
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train[ra[i]].reshape(32,32).T,"gray")
    plt.xlabel(arabic_characters[int(y_train[ra[i]][0])])
plt.show()
# Out:
# (13440, 32, 32, 1) (3360, 32, 32, 1)

# %%
from keras.utils.np_utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
print(y_train.shape, y_test.shape)
for i in zip(y_train[0], arabic_characters):
    print(i)
# Out:
# (13440, 28) (3360, 28)
# (1.0, 'alef')
# (0.0, 'beh')
# (0.0, 'teh')
# (0.0, 'theh')
# (0.0, 'jeem')
# (0.0, 'hah')
# (0.0, 'khah')
# (0.0, 'dal')
# (0.0, 'thal')
# (0.0, 'reh')
# (0.0, 'zain')
# (0.0, 'seen')
# (0.0, 'sheen')
# (0.0, 'sad')
# (0.0, 'dad')
# (0.0, 'tah')
# (0.0, 'zah')
# (0.0, 'ain')
# (0.0, 'ghain')
# (0.0, 'feh')
# (0.0, 'qaf')
# (0.0, 'kaf')
# (0.0, 'lam')
# (0.0, 'meem')
# (0.0, 'noon')
# (0.0, 'heh')
# (0.0, 'waw')
# (0.0, 'yeh')

# %%
len(y_test)
# Out:
# 3360

# %%
model = Sequential()

model.add(Conv2D(64, (3, 3), padding='same',input_shape=shape)) 
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(Conv2D(64, (3, 3))) 
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2))) 
model.add(BatchNormalization())
model.add(Dropout(0.35))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization()) 

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2))) 
model.add(BatchNormalization())
model.add(Dropout(0.35)) #64 --> 42

model.add(Conv2D(64, (3, 3), padding='same')) 
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(Flatten()) 
model.add(Dropout(0.5)) 
model.add(Dense(512)) 
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dense(28)) 
model.add(Activation('softmax'))

model.summary()
# Out:
# 2023-01-15 20:34:03.391419: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-15 20:34:03.399707: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-15 20:34:03.400448: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-15 20:34:03.402485: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        640
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 64)        36928
# _________________________________________________________________
# activation_1 (Activation)    (None, 30, 30, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 15, 15, 64)        256
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 64)        36928
# _________________________________________________________________
# activation_2 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 15, 15, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 6, 6, 64)          256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 6, 6, 64)          36928
# _________________________________________________________________
# activation_4 (Activation)    (None, 6, 6, 64)          0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 6, 6, 64)          256
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1180160
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_1 (Dense)              (None, 28)                14364
# _________________________________________________________________
# activation_6 (Activation)    (None, 28)                0
# =================================================================
# Total params: 1,346,204
# Trainable params: 1,344,540
# Non-trainable params: 1,664
# _________________________________________________________________
# 2023-01-15 20:34:03.402811: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-15 20:34:03.403544: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-15 20:34:03.404224: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-15 20:34:04.043115: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-15 20:34:04.043916: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-15 20:34:04.044610: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-15 20:34:04.045234: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
model.compile(optimizer = 'adam',
               loss = 'categorical_crossentropy',
               metrics = ['accuracy'])

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  
        samplewise_center=False, 
        featurewise_std_normalization=False,  
        samplewise_std_normalization=False,  
        zca_whitening=False, 
        rotation_range=10,  
        zoom_range = 0.2,
        width_shift_range=0.2, 
        height_shift_range=0.2, 
        horizontal_flip=False,  
        vertical_flip=False) 
train_gen = datagen.flow(x_train, y_train, batch_size=32)
test_gen = datagen.flow(x_test, y_test, batch_size=32)

# %%
checkpoint = ModelCheckpoint("cnn.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)

# %%
history = model.fit_generator(train_gen, epochs = 100, validation_data = test_gen, 
                            callbacks=[checkpoint,reduce_lr])
# Out:
# Epoch 1/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1931 - accuracy: 0.9397 - val_loss: 0.1371 - val_accuracy: 0.9610
#
# Epoch 00001: val_accuracy did not improve from 0.96458
# Epoch 2/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1926 - accuracy: 0.9392 - val_loss: 0.1398 - val_accuracy: 0.9613
#
# Epoch 00002: val_accuracy did not improve from 0.96458
# Epoch 3/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1825 - accuracy: 0.9407 - val_loss: 0.1290 - val_accuracy: 0.9595
#
# Epoch 00003: val_accuracy did not improve from 0.96458
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# Epoch 4/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1778 - accuracy: 0.9445 - val_loss: 0.1068 - val_accuracy: 0.9696
#
# Epoch 00004: val_accuracy improved from 0.96458 to 0.96964, saving model to cnn.h5
# Epoch 5/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1633 - accuracy: 0.9490 - val_loss: 0.1118 - val_accuracy: 0.9658
#
# Epoch 00005: val_accuracy did not improve from 0.96964
# Epoch 6/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1715 - accuracy: 0.9487 - val_loss: 0.1126 - val_accuracy: 0.9667
#
# Epoch 00006: val_accuracy did not improve from 0.96964
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# Epoch 7/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1651 - accuracy: 0.9475 - val_loss: 0.1172 - val_accuracy: 0.9664
#
# Epoch 00007: val_accuracy did not improve from 0.96964
# Epoch 8/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1565 - accuracy: 0.9525 - val_loss: 0.1143 - val_accuracy: 0.9676
#
# Epoch 00008: val_accuracy did not improve from 0.96964
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# Epoch 9/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1547 - accuracy: 0.9536 - val_loss: 0.1205 - val_accuracy: 0.9646
#
# Epoch 00009: val_accuracy did not improve from 0.96964
# Epoch 10/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1572 - accuracy: 0.9519 - val_loss: 0.1162 - val_accuracy: 0.9658
#
# Epoch 00010: val_accuracy did not improve from 0.96964
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# Epoch 11/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1582 - accuracy: 0.9516 - val_loss: 0.1094 - val_accuracy: 0.9702
#
# Epoch 00011: val_accuracy improved from 0.96964 to 0.97024, saving model to cnn.h5
# Epoch 12/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1557 - accuracy: 0.9513 - val_loss: 0.1107 - val_accuracy: 0.9676
#
# Epoch 00012: val_accuracy did not improve from 0.97024
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
# Epoch 13/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1491 - accuracy: 0.9547 - val_loss: 0.1247 - val_accuracy: 0.9637
#
# Epoch 00013: val_accuracy did not improve from 0.97024
# Epoch 14/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1587 - accuracy: 0.9501 - val_loss: 0.1140 - val_accuracy: 0.9693
#
# Epoch 00014: val_accuracy did not improve from 0.97024
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 2.1870000637136398e-07.
# Epoch 15/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1564 - accuracy: 0.9524 - val_loss: 0.1145 - val_accuracy: 0.9667
#
# Epoch 00015: val_accuracy did not improve from 0.97024
# Epoch 16/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1565 - accuracy: 0.9492 - val_loss: 0.1064 - val_accuracy: 0.9688
#
# Epoch 00016: val_accuracy did not improve from 0.97024
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 6.561000276406048e-08.
# Epoch 17/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1481 - accuracy: 0.9548 - val_loss: 0.1185 - val_accuracy: 0.9655
#
# Epoch 00017: val_accuracy did not improve from 0.97024
# Epoch 18/100
# 420/420 [==============================] - 7s 17ms/step - loss: 0.1577 - accuracy: 0.9513 - val_loss: 0.1115 - val_accuracy: 0.9670
#
# Epoch 00018: val_accuracy did not improve from 0.97024
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.9683000829218145e-08.
# Epoch 19/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1534 - accuracy: 0.9544 - val_loss: 0.1047 - val_accuracy: 0.9673
#
# Epoch 00019: val_accuracy did not improve from 0.97024
# Epoch 20/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1537 - accuracy: 0.9531 - val_loss: 0.1091 - val_accuracy: 0.9693
#
# Epoch 00020: val_accuracy did not improve from 0.97024
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 5.904900035602622e-09.
# Epoch 21/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1643 - accuracy: 0.9480 - val_loss: 0.1230 - val_accuracy: 0.9640
#
# Epoch 00021: val_accuracy did not improve from 0.97024
# Epoch 22/100
# 420/420 [==============================] - 7s 17ms/step - loss: 0.1535 - accuracy: 0.9522 - val_loss: 0.1146 - val_accuracy: 0.9664
#
# Epoch 00022: val_accuracy did not improve from 0.97024
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 1.7714700373261393e-09.
# Epoch 23/100
# 420/420 [==============================] - 7s 17ms/step - loss: 0.1545 - accuracy: 0.9520 - val_loss: 0.1172 - val_accuracy: 0.9649
#
# Epoch 00023: val_accuracy did not improve from 0.97024
# Epoch 24/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1585 - accuracy: 0.9522 - val_loss: 0.1262 - val_accuracy: 0.9667
#
# Epoch 00024: val_accuracy did not improve from 0.97024
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 5.314410245205181e-10.
# Epoch 25/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1569 - accuracy: 0.9520 - val_loss: 0.1101 - val_accuracy: 0.9708
#
# Epoch 00025: val_accuracy improved from 0.97024 to 0.97083, saving model to cnn.h5
# Epoch 26/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1505 - accuracy: 0.9525 - val_loss: 0.1200 - val_accuracy: 0.9682
#
# Epoch 00026: val_accuracy did not improve from 0.97083
# Epoch 27/100
# 420/420 [==============================] - 7s 15ms/step - loss: 0.1610 - accuracy: 0.9471 - val_loss: 0.1183 - val_accuracy: 0.9688
#
# Epoch 00027: val_accuracy did not improve from 0.97083
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.5943230069481729e-10.
# Epoch 28/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1462 - accuracy: 0.9542 - val_loss: 0.1092 - val_accuracy: 0.9661
#
# Epoch 00028: val_accuracy did not improve from 0.97083
# Epoch 29/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1608 - accuracy: 0.9475 - val_loss: 0.1126 - val_accuracy: 0.9649
#
# Epoch 00029: val_accuracy did not improve from 0.97083
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 4.7829690208445185e-11.
# Epoch 30/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1498 - accuracy: 0.9545 - val_loss: 0.1178 - val_accuracy: 0.9670
#
# Epoch 00030: val_accuracy did not improve from 0.97083
# Epoch 31/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1516 - accuracy: 0.9504 - val_loss: 0.1180 - val_accuracy: 0.9696
#
# Epoch 00031: val_accuracy did not improve from 0.97083
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.434890747886719e-11.
# Epoch 32/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1510 - accuracy: 0.9517 - val_loss: 0.1093 - val_accuracy: 0.9693
#
# Epoch 00032: val_accuracy did not improve from 0.97083
# Epoch 33/100
# 420/420 [==============================] - 7s 17ms/step - loss: 0.1600 - accuracy: 0.9507 - val_loss: 0.1208 - val_accuracy: 0.9664
#
# Epoch 00033: val_accuracy did not improve from 0.97083
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 4.304672243660157e-12.
# Epoch 34/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1523 - accuracy: 0.9516 - val_loss: 0.1205 - val_accuracy: 0.9652
#
# Epoch 00034: val_accuracy did not improve from 0.97083
# Epoch 35/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1559 - accuracy: 0.9510 - val_loss: 0.1174 - val_accuracy: 0.9622
#
# Epoch 00035: val_accuracy did not improve from 0.97083
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 1.2914016210563428e-12.
# Epoch 36/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1597 - accuracy: 0.9498 - val_loss: 0.1128 - val_accuracy: 0.9676
#
# Epoch 00036: val_accuracy did not improve from 0.97083
# Epoch 37/100
# 420/420 [==============================] - 7s 15ms/step - loss: 0.1520 - accuracy: 0.9536 - val_loss: 0.1227 - val_accuracy: 0.9655
#
# Epoch 00037: val_accuracy did not improve from 0.97083
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 3.874204993273289e-13.
# Epoch 38/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1533 - accuracy: 0.9519 - val_loss: 0.1184 - val_accuracy: 0.9658
#
# Epoch 00038: val_accuracy did not improve from 0.97083
# Epoch 39/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1604 - accuracy: 0.9513 - val_loss: 0.1135 - val_accuracy: 0.9696
#
# Epoch 00039: val_accuracy did not improve from 0.97083
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 1.162261530508052e-13.
# Epoch 40/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1620 - accuracy: 0.9469 - val_loss: 0.1151 - val_accuracy: 0.9688
#
# Epoch 00040: val_accuracy did not improve from 0.97083
# Epoch 41/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1560 - accuracy: 0.9512 - val_loss: 0.1174 - val_accuracy: 0.9685
#
# Epoch 00041: val_accuracy did not improve from 0.97083
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 3.4867844288938296e-14.
# Epoch 42/100
# 420/420 [==============================] - 7s 17ms/step - loss: 0.1528 - accuracy: 0.9526 - val_loss: 0.1156 - val_accuracy: 0.9661
#
# Epoch 00042: val_accuracy did not improve from 0.97083
# Epoch 43/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1532 - accuracy: 0.9523 - val_loss: 0.1263 - val_accuracy: 0.9643
#
# Epoch 00043: val_accuracy did not improve from 0.97083
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 1.0460353083393582e-14.
# Epoch 44/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1566 - accuracy: 0.9511 - val_loss: 0.1202 - val_accuracy: 0.9646
#
# Epoch 00044: val_accuracy did not improve from 0.97083
# Epoch 45/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1545 - accuracy: 0.9516 - val_loss: 0.1083 - val_accuracy: 0.9693
#
# Epoch 00045: val_accuracy did not improve from 0.97083
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 3.138105874196098e-15.
# Epoch 46/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1581 - accuracy: 0.9525 - val_loss: 0.1163 - val_accuracy: 0.9661
#
# Epoch 00046: val_accuracy did not improve from 0.97083
# Epoch 47/100
# 420/420 [==============================] - 7s 17ms/step - loss: 0.1570 - accuracy: 0.9512 - val_loss: 0.1146 - val_accuracy: 0.9673
#
# Epoch 00047: val_accuracy did not improve from 0.97083
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 9.414317622588293e-16.
# Epoch 48/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1579 - accuracy: 0.9525 - val_loss: 0.1188 - val_accuracy: 0.9679
#
# Epoch 00048: val_accuracy did not improve from 0.97083
# Epoch 49/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1628 - accuracy: 0.9499 - val_loss: 0.1123 - val_accuracy: 0.9673
#
# Epoch 00049: val_accuracy did not improve from 0.97083
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 2.8242954138314303e-16.
# Epoch 50/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1586 - accuracy: 0.9507 - val_loss: 0.1202 - val_accuracy: 0.9673
#
# Epoch 00050: val_accuracy did not improve from 0.97083
# Epoch 51/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1548 - accuracy: 0.9515 - val_loss: 0.1155 - val_accuracy: 0.9667
#
# Epoch 00051: val_accuracy did not improve from 0.97083
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 8.472885923856935e-17.
# Epoch 52/100
# 420/420 [==============================] - 7s 17ms/step - loss: 0.1552 - accuracy: 0.9518 - val_loss: 0.1122 - val_accuracy: 0.9658
#
# Epoch 00052: val_accuracy did not improve from 0.97083
# Epoch 53/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1472 - accuracy: 0.9533 - val_loss: 0.1117 - val_accuracy: 0.9655
#
# Epoch 00053: val_accuracy did not improve from 0.97083
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 2.541865737452411e-17.
# Epoch 54/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1589 - accuracy: 0.9501 - val_loss: 0.1198 - val_accuracy: 0.9682
#
# Epoch 00054: val_accuracy did not improve from 0.97083
# Epoch 55/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1607 - accuracy: 0.9511 - val_loss: 0.1046 - val_accuracy: 0.9708
#
# Epoch 00055: val_accuracy did not improve from 0.97083
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 7.62559741088058e-18.
# Epoch 56/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1586 - accuracy: 0.9499 - val_loss: 0.1183 - val_accuracy: 0.9628
#
# Epoch 00056: val_accuracy did not improve from 0.97083
# Epoch 57/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1569 - accuracy: 0.9515 - val_loss: 0.1171 - val_accuracy: 0.9661
#
# Epoch 00057: val_accuracy did not improve from 0.97083
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 2.2876793225258477e-18.
# Epoch 58/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1550 - accuracy: 0.9516 - val_loss: 0.1311 - val_accuracy: 0.9661
#
# Epoch 00058: val_accuracy did not improve from 0.97083
# Epoch 59/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1524 - accuracy: 0.9525 - val_loss: 0.1317 - val_accuracy: 0.9655
#
# Epoch 00059: val_accuracy did not improve from 0.97083
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 6.863037719423359e-19.
# Epoch 60/100
# 420/420 [==============================] - 7s 15ms/step - loss: 0.1489 - accuracy: 0.9530 - val_loss: 0.1120 - val_accuracy: 0.9682
#
# Epoch 00060: val_accuracy did not improve from 0.97083
# Epoch 61/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1598 - accuracy: 0.9490 - val_loss: 0.1170 - val_accuracy: 0.9685
#
# Epoch 00061: val_accuracy did not improve from 0.97083
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 2.0589113778655536e-19.
# Epoch 62/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1564 - accuracy: 0.9522 - val_loss: 0.1097 - val_accuracy: 0.9714
#
# Epoch 00062: val_accuracy improved from 0.97083 to 0.97143, saving model to cnn.h5
# Epoch 63/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1564 - accuracy: 0.9506 - val_loss: 0.1060 - val_accuracy: 0.9741
#
# Epoch 00063: val_accuracy improved from 0.97143 to 0.97411, saving model to cnn.h5
# Epoch 64/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1548 - accuracy: 0.9510 - val_loss: 0.1165 - val_accuracy: 0.9670
#
# Epoch 00064: val_accuracy did not improve from 0.97411
# Epoch 65/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1559 - accuracy: 0.9519 - val_loss: 0.1228 - val_accuracy: 0.9649
#
# Epoch 00065: val_accuracy did not improve from 0.97411
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 6.176734056048479e-20.
# Epoch 66/100
# 420/420 [==============================] - 7s 17ms/step - loss: 0.1522 - accuracy: 0.9535 - val_loss: 0.1131 - val_accuracy: 0.9688
#
# Epoch 00066: val_accuracy did not improve from 0.97411
# Epoch 67/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1564 - accuracy: 0.9510 - val_loss: 0.1189 - val_accuracy: 0.9673
#
# Epoch 00067: val_accuracy did not improve from 0.97411
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 1.8530202168145436e-20.
# Epoch 68/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1595 - accuracy: 0.9513 - val_loss: 0.1079 - val_accuracy: 0.9693
#
# Epoch 00068: val_accuracy did not improve from 0.97411
# Epoch 69/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1477 - accuracy: 0.9548 - val_loss: 0.1144 - val_accuracy: 0.9673
#
# Epoch 00069: val_accuracy did not improve from 0.97411
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 5.559060844314087e-21.
# Epoch 70/100
# 420/420 [==============================] - 7s 17ms/step - loss: 0.1522 - accuracy: 0.9517 - val_loss: 0.1113 - val_accuracy: 0.9676
#
# Epoch 00070: val_accuracy did not improve from 0.97411
# Epoch 71/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1619 - accuracy: 0.9478 - val_loss: 0.1131 - val_accuracy: 0.9679
#
# Epoch 00071: val_accuracy did not improve from 0.97411
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 1.667718253294226e-21.
# Epoch 72/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1597 - accuracy: 0.9504 - val_loss: 0.1087 - val_accuracy: 0.9655
#
# Epoch 00072: val_accuracy did not improve from 0.97411
# Epoch 73/100
# 420/420 [==============================] - 7s 15ms/step - loss: 0.1536 - accuracy: 0.9513 - val_loss: 0.1191 - val_accuracy: 0.9682
#
# Epoch 00073: val_accuracy did not improve from 0.97411
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 5.003154881051713e-22.
# Epoch 74/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1539 - accuracy: 0.9512 - val_loss: 0.1065 - val_accuracy: 0.9726
#
# Epoch 00074: val_accuracy did not improve from 0.97411
# Epoch 75/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1559 - accuracy: 0.9503 - val_loss: 0.1126 - val_accuracy: 0.9661
#
# Epoch 00075: val_accuracy did not improve from 0.97411
#
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 1.500946434023255e-22.
# Epoch 76/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1579 - accuracy: 0.9514 - val_loss: 0.1240 - val_accuracy: 0.9658
#
# Epoch 00076: val_accuracy did not improve from 0.97411
# Epoch 77/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1605 - accuracy: 0.9504 - val_loss: 0.1098 - val_accuracy: 0.9682
#
# Epoch 00077: val_accuracy did not improve from 0.97411
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 4.5028393778004124e-23.
# Epoch 78/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1543 - accuracy: 0.9525 - val_loss: 0.1152 - val_accuracy: 0.9670
#
# Epoch 00078: val_accuracy did not improve from 0.97411
# Epoch 79/100
# 420/420 [==============================] - 6s 14ms/step - loss: 0.1611 - accuracy: 0.9495 - val_loss: 0.1186 - val_accuracy: 0.9664
#
# Epoch 00079: val_accuracy did not improve from 0.97411
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 1.350851851205447e-23.
# Epoch 80/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1547 - accuracy: 0.9515 - val_loss: 0.1273 - val_accuracy: 0.9634
#
# Epoch 00080: val_accuracy did not improve from 0.97411
# Epoch 81/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1531 - accuracy: 0.9535 - val_loss: 0.1277 - val_accuracy: 0.9622
#
# Epoch 00081: val_accuracy did not improve from 0.97411
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 4.05255564827965e-24.
# Epoch 82/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1569 - accuracy: 0.9509 - val_loss: 0.1148 - val_accuracy: 0.9670
#
# Epoch 00082: val_accuracy did not improve from 0.97411
# Epoch 83/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1566 - accuracy: 0.9513 - val_loss: 0.1112 - val_accuracy: 0.9655
#
# Epoch 00083: val_accuracy did not improve from 0.97411
#
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 1.2157666708180678e-24.
# Epoch 84/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1561 - accuracy: 0.9512 - val_loss: 0.1170 - val_accuracy: 0.9646
#
# Epoch 00084: val_accuracy did not improve from 0.97411
# Epoch 85/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1550 - accuracy: 0.9513 - val_loss: 0.1102 - val_accuracy: 0.9664
#
# Epoch 00085: val_accuracy did not improve from 0.97411
#
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 3.6473000716187714e-25.
# Epoch 86/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1560 - accuracy: 0.9513 - val_loss: 0.1186 - val_accuracy: 0.9667
#
# Epoch 00086: val_accuracy did not improve from 0.97411
# Epoch 87/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1533 - accuracy: 0.9522 - val_loss: 0.1123 - val_accuracy: 0.9673
#
# Epoch 00087: val_accuracy did not improve from 0.97411
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 1.0941900362767734e-25.
# Epoch 88/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1553 - accuracy: 0.9519 - val_loss: 0.1117 - val_accuracy: 0.9720
#
# Epoch 00088: val_accuracy did not improve from 0.97411
# Epoch 89/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1589 - accuracy: 0.9510 - val_loss: 0.1088 - val_accuracy: 0.9676
#
# Epoch 00089: val_accuracy did not improve from 0.97411
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 3.28257003487461e-26.
# Epoch 90/100
# 420/420 [==============================] - 7s 17ms/step - loss: 0.1545 - accuracy: 0.9493 - val_loss: 0.1077 - val_accuracy: 0.9688
#
# Epoch 00090: val_accuracy did not improve from 0.97411
# Epoch 91/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1626 - accuracy: 0.9481 - val_loss: 0.1225 - val_accuracy: 0.9649
#
# Epoch 00091: val_accuracy did not improve from 0.97411
#
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 9.847710289513105e-27.
# Epoch 92/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1590 - accuracy: 0.9531 - val_loss: 0.1089 - val_accuracy: 0.9708
#
# Epoch 00092: val_accuracy did not improve from 0.97411
# Epoch 93/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1550 - accuracy: 0.9519 - val_loss: 0.1201 - val_accuracy: 0.9673
#
# Epoch 00093: val_accuracy did not improve from 0.97411
#
# Epoch 00093: ReduceLROnPlateau reducing learning rate to 2.9543131330762504e-27.
# Epoch 94/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1598 - accuracy: 0.9496 - val_loss: 0.1153 - val_accuracy: 0.9688
#
# Epoch 00094: val_accuracy did not improve from 0.97411
# Epoch 95/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1539 - accuracy: 0.9533 - val_loss: 0.1169 - val_accuracy: 0.9676
#
# Epoch 00095: val_accuracy did not improve from 0.97411
#
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 8.862939514784548e-28.
# Epoch 96/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1624 - accuracy: 0.9498 - val_loss: 0.1178 - val_accuracy: 0.9661
#
# Epoch 00096: val_accuracy did not improve from 0.97411
# Epoch 97/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1557 - accuracy: 0.9510 - val_loss: 0.1258 - val_accuracy: 0.9649
#
# Epoch 00097: val_accuracy did not improve from 0.97411
#
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 2.658881969991161e-28.
# Epoch 98/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1639 - accuracy: 0.9493 - val_loss: 0.1075 - val_accuracy: 0.9661
#
# Epoch 00098: val_accuracy did not improve from 0.97411
# Epoch 99/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1481 - accuracy: 0.9542 - val_loss: 0.1087 - val_accuracy: 0.9682
#
# Epoch 00099: val_accuracy did not improve from 0.97411
#
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 7.976646198862975e-29.
# Epoch 100/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1590 - accuracy: 0.9512 - val_loss: 0.1220 - val_accuracy: 0.9649
#
# Epoch 00100: val_accuracy did not improve from 0.97411

# %%
fig = plt.figure(figsize=(18, 9))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

fig = plt.figure(figsize=(18, 9))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
score = model.evaluate(x_test, y_test)
print('Test accuarcy: %0.2f%%' % (score[0] * 100))
# Out:
# 105/105 [==============================] - 1s 3ms/step - loss: 0.0755 - accuracy: 0.9827
# Test accuarcy: 7.55%

# %%
plt.imshow(x_test[20])
plt.show()

# %%
pred = model.predict(x_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       120
#            1       1.00      0.99      1.00       120
#            2       0.96      0.98      0.97       120
#            3       1.00      0.99      1.00       120
#            4       0.99      1.00      1.00       120
#            5       0.98      0.99      0.99       120
#            6       1.00      0.99      1.00       120
#            7       0.97      0.96      0.97       120
#            8       0.97      0.95      0.96       120
#            9       0.95      0.97      0.96       120
#           10       0.97      0.93      0.95       120
#           11       1.00      0.99      1.00       120
#           12       0.99      1.00      1.00       120
#           13       0.97      1.00      0.98       120
#           14       1.00      0.97      0.98       120
#           15       0.96      0.99      0.98       120
#           16       1.00      0.96      0.98       120
#           17       0.99      0.98      0.99       120
#           18       0.99      1.00      1.00       120
#           19       0.98      0.99      0.98       120
#           20       0.98      0.97      0.98       120
#           21       0.99      0.99      0.99       120
#           22       0.98      1.00      0.99       120
#           23       0.99      0.98      0.99       120
#           24       0.98      0.96      0.97       120
#           25       0.97      0.99      0.98       120
#           26       0.98      0.97      0.98       120
#           27       0.99      1.00      1.00       120
#
#     accuracy                           0.98      3360
#    macro avg       0.98      0.98      0.98      3360
# weighted avg       0.98      0.98      0.98      3360

# %%
from sklearn.metrics import confusion_matrix

fig,ax=plt.subplots(1,1,figsize=(28,25))
sns.heatmap(confusion_matrix(y_test_new,pred),ax=ax,xticklabels=arabic_characters,yticklabels=arabic_characters,annot=True,fmt=".1f",cmap="crest")


plt.show()
