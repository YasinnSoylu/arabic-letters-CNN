# %% [markdown]
# <a href="https://www.kaggle.com/code/yasinsoylu123/arabic-letters?scriptVersionId=124239320" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import Image, display
import random
import math
import tensorflow as tf
from keras.preprocessing.image import load_img,img_to_array,ImageDataGenerator
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.utils import plot_model 
from tensorflow.keras.layers import Input, Dense, Dropout, Flatten, Activation,Concatenate
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.utils import to_categorical 
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras import backend, models
from sklearn.metrics import confusion_matrix
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from tensorflow.keras.applications import VGG16, MobileNet
from keras.applications.vgg16 import preprocess_input

# %%
arabic_characters = ['alef', 'beh', 'teh', 'theh', 'jeem', 'hah', 'khah', 'dal', 'thal',
                    'reh', 'zain', 'seen', 'sheen', 'sad', 'dad', 'tah', 'zah', 'ain',
                    'ghain', 'feh', 'qaf', 'kaf', 'lam', 'meem', 'noon', 'heh', 'waw', 'yeh']

# %%
x_train = pd.read_csv("/kaggle/input/ahcd1/csvTrainImages 13440x1024.csv",header=None).to_numpy()
y_train = pd.read_csv("/kaggle/input/ahcd1/csvTrainLabel 13440x1.csv",header=None).to_numpy()-1 

x_test = pd.read_csv("/kaggle/input/ahcd1/csvTestImages 3360x1024.csv",header=None).to_numpy()
y_test = pd.read_csv("/kaggle/input/ahcd1/csvTestLabel 3360x1.csv",header=None).to_numpy()-1

print("x_train.shape =", x_train.shape, "\ny_train.shape =", y_train.shape, "\nx_test.shape =", x_test.shape, "\ny_test.shape =", y_test.shape)
# Out:
# x_train.shape = (13440, 1024)
# y_train.shape = (13440, 1)
# x_test.shape = (3360, 1024)
# y_test.shape = (3360, 1)

# %%
shape=(32,32,1)

# %%
x_train = x_train.reshape(-1,32,32,1)
x_test = x_test.reshape(-1,32,32,1)

x_train = x_train / 255.0
x_test = x_test / 255.0

print(x_train.shape, x_test.shape)

ra = np.random.randint(0, 13440, size=25)
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train[ra[i]].reshape(32,32).T,"gray")
    plt.xlabel(arabic_characters[int(y_train[ra[i]][0])])
plt.show()
# Out:
# (13440, 32, 32, 1) (3360, 32, 32, 1)

# %%
from keras.utils.np_utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
print(y_train.shape, y_test.shape)
for i in zip(y_train[0], arabic_characters):
    print(i)
# Out:
# (13440, 28) (3360, 28)
# (1.0, 'alef')
# (0.0, 'beh')
# (0.0, 'teh')
# (0.0, 'theh')
# (0.0, 'jeem')
# (0.0, 'hah')
# (0.0, 'khah')
# (0.0, 'dal')
# (0.0, 'thal')
# (0.0, 'reh')
# (0.0, 'zain')
# (0.0, 'seen')
# (0.0, 'sheen')
# (0.0, 'sad')
# (0.0, 'dad')
# (0.0, 'tah')
# (0.0, 'zah')
# (0.0, 'ain')
# (0.0, 'ghain')
# (0.0, 'feh')
# (0.0, 'qaf')
# (0.0, 'kaf')
# (0.0, 'lam')
# (0.0, 'meem')
# (0.0, 'noon')
# (0.0, 'heh')
# (0.0, 'waw')
# (0.0, 'yeh')

# %%
len(y_test)
# Out:
# 3360

# %%
model = Sequential()

model.add(Conv2D(64, (3, 3), padding='same',input_shape=shape)) 
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(Conv2D(64, (3, 3))) 
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2))) 
model.add(BatchNormalization())
model.add(Dropout(0.35))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization()) 

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2))) 
model.add(BatchNormalization())
model.add(Dropout(0.35)) #64 --> 42

model.add(Conv2D(64, (3, 3), padding='same')) 
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(Flatten()) 
model.add(Dropout(0.5)) 
model.add(Dense(512)) 
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dense(28)) 
model.add(Activation('softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        640
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 64)        36928
# _________________________________________________________________
# activation_1 (Activation)    (None, 30, 30, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 15, 15, 64)        256
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 64)        36928
# _________________________________________________________________
# activation_2 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 15, 15, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 6, 6, 64)          256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 6, 6, 64)          36928
# _________________________________________________________________
# activation_4 (Activation)    (None, 6, 6, 64)          0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 6, 6, 64)          256
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1180160
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_1 (Dense)              (None, 28)                14364
# _________________________________________________________________
# activation_6 (Activation)    (None, 28)                0
# =================================================================
# Total params: 1,346,204
# Trainable params: 1,344,540
# Non-trainable params: 1,664
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam',
               loss = 'categorical_crossentropy',
               metrics = ['accuracy'])

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  
        samplewise_center=False, 
        featurewise_std_normalization=False,  
        samplewise_std_normalization=False,  
        zca_whitening=False, 
        rotation_range=10,  
        zoom_range = 0.2,
        width_shift_range=0.2, 
        height_shift_range=0.2, 
        horizontal_flip=False,  
        vertical_flip=False) 
train_gen = datagen.flow(x_train, y_train, batch_size=32)
test_gen = datagen.flow(x_test, y_test, batch_size=32)

# %%
checkpoint = ModelCheckpoint("cnn.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)

# %%
history = model.fit_generator(train_gen, epochs = 100, validation_data = test_gen, 
                            callbacks=[checkpoint,reduce_lr])
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 420/420 [==============================] - 14s 15ms/step - loss: 2.2639 - accuracy: 0.3489 - val_loss: 4.7755 - val_accuracy: 0.1074
#
# Epoch 00001: val_accuracy improved from -inf to 0.10744, saving model to cnn.h5
# Epoch 2/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.9962 - accuracy: 0.6759 - val_loss: 0.7088 - val_accuracy: 0.7601
#
# Epoch 00002: val_accuracy improved from 0.10744 to 0.76012, saving model to cnn.h5
# Epoch 3/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.7161 - accuracy: 0.7650 - val_loss: 1.2632 - val_accuracy: 0.5949
#
# Epoch 00003: val_accuracy did not improve from 0.76012
# Epoch 4/100
# 420/420 [==============================] - 6s 14ms/step - loss: 0.5752 - accuracy: 0.8118 - val_loss: 0.4130 - val_accuracy: 0.8759
#
# Epoch 00004: val_accuracy improved from 0.76012 to 0.87589, saving model to cnn.h5
# Epoch 5/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.4970 - accuracy: 0.8406 - val_loss: 0.4173 - val_accuracy: 0.8741
#
# Epoch 00005: val_accuracy did not improve from 0.87589
# Epoch 6/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.4476 - accuracy: 0.8580 - val_loss: 0.3418 - val_accuracy: 0.8914
#
# Epoch 00006: val_accuracy improved from 0.87589 to 0.89137, saving model to cnn.h5
# Epoch 7/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.4041 - accuracy: 0.8702 - val_loss: 0.3070 - val_accuracy: 0.8979
#
# Epoch 00007: val_accuracy improved from 0.89137 to 0.89792, saving model to cnn.h5
# Epoch 8/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.3794 - accuracy: 0.8777 - val_loss: 0.3818 - val_accuracy: 0.8756
#
# Epoch 00008: val_accuracy did not improve from 0.89792
# Epoch 9/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.3529 - accuracy: 0.8891 - val_loss: 1.0436 - val_accuracy: 0.6402
#
# Epoch 00009: val_accuracy did not improve from 0.89792
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# Epoch 10/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.2737 - accuracy: 0.9144 - val_loss: 0.1710 - val_accuracy: 0.9482
#
# Epoch 00010: val_accuracy improved from 0.89792 to 0.94821, saving model to cnn.h5
# Epoch 11/100
# 420/420 [==============================] - 6s 14ms/step - loss: 0.2494 - accuracy: 0.9208 - val_loss: 0.2775 - val_accuracy: 0.9104
#
# Epoch 00011: val_accuracy did not improve from 0.94821
# Epoch 12/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.2446 - accuracy: 0.9245 - val_loss: 0.1790 - val_accuracy: 0.9467
#
# Epoch 00012: val_accuracy did not improve from 0.94821
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# Epoch 13/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.2191 - accuracy: 0.9315 - val_loss: 0.1428 - val_accuracy: 0.9542
#
# Epoch 00013: val_accuracy improved from 0.94821 to 0.95417, saving model to cnn.h5
# Epoch 14/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.2131 - accuracy: 0.9338 - val_loss: 0.1436 - val_accuracy: 0.9560
#
# Epoch 00014: val_accuracy improved from 0.95417 to 0.95595, saving model to cnn.h5
# Epoch 15/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.2020 - accuracy: 0.9358 - val_loss: 0.1420 - val_accuracy: 0.9592
#
# Epoch 00015: val_accuracy improved from 0.95595 to 0.95923, saving model to cnn.h5
# Epoch 16/100
# 420/420 [==============================] - 6s 14ms/step - loss: 0.2027 - accuracy: 0.9359 - val_loss: 0.1444 - val_accuracy: 0.9580
#
# Epoch 00016: val_accuracy did not improve from 0.95923
# Epoch 17/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.2031 - accuracy: 0.9370 - val_loss: 0.1371 - val_accuracy: 0.9574
#
# Epoch 00017: val_accuracy did not improve from 0.95923
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# Epoch 18/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1977 - accuracy: 0.9393 - val_loss: 0.1356 - val_accuracy: 0.9601
#
# Epoch 00018: val_accuracy improved from 0.95923 to 0.96012, saving model to cnn.h5
# Epoch 19/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1882 - accuracy: 0.9406 - val_loss: 0.1371 - val_accuracy: 0.9592
#
# Epoch 00019: val_accuracy did not improve from 0.96012
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# Epoch 20/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1869 - accuracy: 0.9425 - val_loss: 0.1296 - val_accuracy: 0.9628
#
# Epoch 00020: val_accuracy improved from 0.96012 to 0.96280, saving model to cnn.h5
# Epoch 21/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1905 - accuracy: 0.9407 - val_loss: 0.1240 - val_accuracy: 0.9637
#
# Epoch 00021: val_accuracy improved from 0.96280 to 0.96369, saving model to cnn.h5
# Epoch 22/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1840 - accuracy: 0.9410 - val_loss: 0.1277 - val_accuracy: 0.9622
#
# Epoch 00022: val_accuracy did not improve from 0.96369
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# Epoch 23/100
# 420/420 [==============================] - 6s 14ms/step - loss: 0.1914 - accuracy: 0.9400 - val_loss: 0.1344 - val_accuracy: 0.9628
#
# Epoch 00023: val_accuracy did not improve from 0.96369
# Epoch 24/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1823 - accuracy: 0.9426 - val_loss: 0.1220 - val_accuracy: 0.9673
#
# Epoch 00024: val_accuracy improved from 0.96369 to 0.96726, saving model to cnn.h5
# Epoch 25/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1893 - accuracy: 0.9411 - val_loss: 0.1165 - val_accuracy: 0.9658
#
# Epoch 00025: val_accuracy did not improve from 0.96726
# Epoch 26/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1981 - accuracy: 0.9385 - val_loss: 0.1274 - val_accuracy: 0.9640
#
# Epoch 00026: val_accuracy did not improve from 0.96726
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
# Epoch 27/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1861 - accuracy: 0.9410 - val_loss: 0.1260 - val_accuracy: 0.9613
#
# Epoch 00027: val_accuracy did not improve from 0.96726
# Epoch 28/100
# 420/420 [==============================] - 6s 14ms/step - loss: 0.1840 - accuracy: 0.9426 - val_loss: 0.1267 - val_accuracy: 0.9622
#
# Epoch 00028: val_accuracy did not improve from 0.96726
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 2.1870000637136398e-07.
# Epoch 29/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1809 - accuracy: 0.9426 - val_loss: 0.1372 - val_accuracy: 0.9613
#
# Epoch 00029: val_accuracy did not improve from 0.96726
# Epoch 30/100
# 420/420 [==============================] - 6s 14ms/step - loss: 0.1875 - accuracy: 0.9413 - val_loss: 0.1247 - val_accuracy: 0.9631
#
# Epoch 00030: val_accuracy did not improve from 0.96726
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 6.561000276406048e-08.
# Epoch 31/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1858 - accuracy: 0.9451 - val_loss: 0.1262 - val_accuracy: 0.9631
#
# Epoch 00031: val_accuracy did not improve from 0.96726
# Epoch 32/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1801 - accuracy: 0.9453 - val_loss: 0.1264 - val_accuracy: 0.9646
#
# Epoch 00032: val_accuracy did not improve from 0.96726
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 1.9683000829218145e-08.
# Epoch 33/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1876 - accuracy: 0.9420 - val_loss: 0.1336 - val_accuracy: 0.9589
#
# Epoch 00033: val_accuracy did not improve from 0.96726
# Epoch 34/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1784 - accuracy: 0.9418 - val_loss: 0.1262 - val_accuracy: 0.9643
#
# Epoch 00034: val_accuracy did not improve from 0.96726
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 5.904900035602622e-09.
# Epoch 35/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1866 - accuracy: 0.9414 - val_loss: 0.1381 - val_accuracy: 0.9574
#
# Epoch 00035: val_accuracy did not improve from 0.96726
# Epoch 36/100
# 420/420 [==============================] - 7s 17ms/step - loss: 0.1824 - accuracy: 0.9419 - val_loss: 0.1237 - val_accuracy: 0.9655
#
# Epoch 00036: val_accuracy did not improve from 0.96726
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1.7714700373261393e-09.
# Epoch 37/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1832 - accuracy: 0.9443 - val_loss: 0.1306 - val_accuracy: 0.9610
#
# Epoch 00037: val_accuracy did not improve from 0.96726
# Epoch 38/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1783 - accuracy: 0.9441 - val_loss: 0.1211 - val_accuracy: 0.9652
#
# Epoch 00038: val_accuracy did not improve from 0.96726
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 5.314410245205181e-10.
# Epoch 39/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1816 - accuracy: 0.9432 - val_loss: 0.1264 - val_accuracy: 0.9637
#
# Epoch 00039: val_accuracy did not improve from 0.96726
# Epoch 40/100
# 420/420 [==============================] - 6s 14ms/step - loss: 0.1908 - accuracy: 0.9382 - val_loss: 0.1355 - val_accuracy: 0.9616
#
# Epoch 00040: val_accuracy did not improve from 0.96726
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1.5943230069481729e-10.
# Epoch 41/100
# 420/420 [==============================] - 7s 17ms/step - loss: 0.1846 - accuracy: 0.9428 - val_loss: 0.1356 - val_accuracy: 0.9592
#
# Epoch 00041: val_accuracy did not improve from 0.96726
# Epoch 42/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1789 - accuracy: 0.9440 - val_loss: 0.1197 - val_accuracy: 0.9664
#
# Epoch 00042: val_accuracy did not improve from 0.96726
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 4.7829690208445185e-11.
# Epoch 43/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1861 - accuracy: 0.9420 - val_loss: 0.1398 - val_accuracy: 0.9551
#
# Epoch 00043: val_accuracy did not improve from 0.96726
# Epoch 44/100
# 420/420 [==============================] - 6s 14ms/step - loss: 0.1951 - accuracy: 0.9386 - val_loss: 0.1380 - val_accuracy: 0.9577
#
# Epoch 00044: val_accuracy did not improve from 0.96726
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 1.434890747886719e-11.
# Epoch 45/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1779 - accuracy: 0.9463 - val_loss: 0.1224 - val_accuracy: 0.9655
#
# Epoch 00045: val_accuracy did not improve from 0.96726
# Epoch 46/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1849 - accuracy: 0.9417 - val_loss: 0.1320 - val_accuracy: 0.9595
#
# Epoch 00046: val_accuracy did not improve from 0.96726
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 4.304672243660157e-12.
# Epoch 47/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1852 - accuracy: 0.9411 - val_loss: 0.1301 - val_accuracy: 0.9586
#
# Epoch 00047: val_accuracy did not improve from 0.96726
# Epoch 48/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1834 - accuracy: 0.9412 - val_loss: 0.1275 - val_accuracy: 0.9643
#
# Epoch 00048: val_accuracy did not improve from 0.96726
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 1.2914016210563428e-12.
# Epoch 49/100
# 420/420 [==============================] - 6s 14ms/step - loss: 0.1831 - accuracy: 0.9414 - val_loss: 0.1286 - val_accuracy: 0.9619
#
# Epoch 00049: val_accuracy did not improve from 0.96726
# Epoch 50/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1896 - accuracy: 0.9422 - val_loss: 0.1340 - val_accuracy: 0.9568
#
# Epoch 00050: val_accuracy did not improve from 0.96726
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 3.874204993273289e-13.
# Epoch 51/100
# 420/420 [==============================] - 7s 17ms/step - loss: 0.1899 - accuracy: 0.9406 - val_loss: 0.1250 - val_accuracy: 0.9667
#
# Epoch 00051: val_accuracy did not improve from 0.96726
# Epoch 52/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1823 - accuracy: 0.9426 - val_loss: 0.1263 - val_accuracy: 0.9637
#
# Epoch 00052: val_accuracy did not improve from 0.96726
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 1.162261530508052e-13.
# Epoch 53/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1844 - accuracy: 0.9411 - val_loss: 0.1434 - val_accuracy: 0.9577
#
# Epoch 00053: val_accuracy did not improve from 0.96726
# Epoch 54/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1821 - accuracy: 0.9438 - val_loss: 0.1360 - val_accuracy: 0.9592
#
# Epoch 00054: val_accuracy did not improve from 0.96726
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 3.4867844288938296e-14.
# Epoch 55/100
# 420/420 [==============================] - 6s 14ms/step - loss: 0.1886 - accuracy: 0.9402 - val_loss: 0.1262 - val_accuracy: 0.9655
#
# Epoch 00055: val_accuracy did not improve from 0.96726
# Epoch 56/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1898 - accuracy: 0.9410 - val_loss: 0.1342 - val_accuracy: 0.9604
#
# Epoch 00056: val_accuracy did not improve from 0.96726
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 1.0460353083393582e-14.
# Epoch 57/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1851 - accuracy: 0.9427 - val_loss: 0.1358 - val_accuracy: 0.9631
#
# Epoch 00057: val_accuracy did not improve from 0.96726
# Epoch 58/100
# 420/420 [==============================] - 6s 14ms/step - loss: 0.1900 - accuracy: 0.9407 - val_loss: 0.1395 - val_accuracy: 0.9583
#
# Epoch 00058: val_accuracy did not improve from 0.96726
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 3.138105874196098e-15.
# Epoch 59/100
# 420/420 [==============================] - 6s 14ms/step - loss: 0.1767 - accuracy: 0.9430 - val_loss: 0.1413 - val_accuracy: 0.9601
#
# Epoch 00059: val_accuracy did not improve from 0.96726
# Epoch 60/100
# 420/420 [==============================] - 6s 14ms/step - loss: 0.1818 - accuracy: 0.9433 - val_loss: 0.1253 - val_accuracy: 0.9640
#
# Epoch 00060: val_accuracy did not improve from 0.96726
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 9.414317622588293e-16.
# Epoch 61/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1914 - accuracy: 0.9420 - val_loss: 0.1291 - val_accuracy: 0.9604
#
# Epoch 00061: val_accuracy did not improve from 0.96726
# Epoch 62/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1862 - accuracy: 0.9434 - val_loss: 0.1428 - val_accuracy: 0.9580
#
# Epoch 00062: val_accuracy did not improve from 0.96726
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 2.8242954138314303e-16.
# Epoch 63/100
# 420/420 [==============================] - 6s 14ms/step - loss: 0.1881 - accuracy: 0.9400 - val_loss: 0.1243 - val_accuracy: 0.9652
#
# Epoch 00063: val_accuracy did not improve from 0.96726
# Epoch 64/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1784 - accuracy: 0.9440 - val_loss: 0.1241 - val_accuracy: 0.9646
#
# Epoch 00064: val_accuracy did not improve from 0.96726
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 8.472885923856935e-17.
# Epoch 65/100
# 420/420 [==============================] - 6s 14ms/step - loss: 0.1829 - accuracy: 0.9427 - val_loss: 0.1387 - val_accuracy: 0.9563
#
# Epoch 00065: val_accuracy did not improve from 0.96726
# Epoch 66/100
# 420/420 [==============================] - 7s 17ms/step - loss: 0.1890 - accuracy: 0.9409 - val_loss: 0.1341 - val_accuracy: 0.9595
#
# Epoch 00066: val_accuracy did not improve from 0.96726
#
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 2.541865737452411e-17.
# Epoch 67/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1812 - accuracy: 0.9426 - val_loss: 0.1325 - val_accuracy: 0.9595
#
# Epoch 00067: val_accuracy did not improve from 0.96726
# Epoch 68/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1898 - accuracy: 0.9389 - val_loss: 0.1280 - val_accuracy: 0.9619
#
# Epoch 00068: val_accuracy did not improve from 0.96726
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 7.62559741088058e-18.
# Epoch 69/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1902 - accuracy: 0.9415 - val_loss: 0.1233 - val_accuracy: 0.9661
#
# Epoch 00069: val_accuracy did not improve from 0.96726
# Epoch 70/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1773 - accuracy: 0.9469 - val_loss: 0.1458 - val_accuracy: 0.9589
#
# Epoch 00070: val_accuracy did not improve from 0.96726
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 2.2876793225258477e-18.
# Epoch 71/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1832 - accuracy: 0.9414 - val_loss: 0.1212 - val_accuracy: 0.9661
#
# Epoch 00071: val_accuracy did not improve from 0.96726
# Epoch 72/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1822 - accuracy: 0.9431 - val_loss: 0.1281 - val_accuracy: 0.9640
#
# Epoch 00072: val_accuracy did not improve from 0.96726
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 6.863037719423359e-19.
# Epoch 73/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1932 - accuracy: 0.9413 - val_loss: 0.1384 - val_accuracy: 0.9622
#
# Epoch 00073: val_accuracy did not improve from 0.96726
# Epoch 74/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1871 - accuracy: 0.9411 - val_loss: 0.1221 - val_accuracy: 0.9619
#
# Epoch 00074: val_accuracy did not improve from 0.96726
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 2.0589113778655536e-19.
# Epoch 75/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1881 - accuracy: 0.9419 - val_loss: 0.1238 - val_accuracy: 0.9628
#
# Epoch 00075: val_accuracy did not improve from 0.96726
# Epoch 76/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1793 - accuracy: 0.9415 - val_loss: 0.1292 - val_accuracy: 0.9652
#
# Epoch 00076: val_accuracy did not improve from 0.96726
#
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 6.176734056048479e-20.
# Epoch 77/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1807 - accuracy: 0.9435 - val_loss: 0.1420 - val_accuracy: 0.9610
#
# Epoch 00077: val_accuracy did not improve from 0.96726
# Epoch 78/100
# 420/420 [==============================] - 6s 14ms/step - loss: 0.1790 - accuracy: 0.9445 - val_loss: 0.1332 - val_accuracy: 0.9586
#
# Epoch 00078: val_accuracy did not improve from 0.96726
#
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 1.8530202168145436e-20.
# Epoch 79/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1822 - accuracy: 0.9432 - val_loss: 0.1261 - val_accuracy: 0.9619
#
# Epoch 00079: val_accuracy did not improve from 0.96726
# Epoch 80/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1830 - accuracy: 0.9448 - val_loss: 0.1298 - val_accuracy: 0.9586
#
# Epoch 00080: val_accuracy did not improve from 0.96726
#
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 5.559060844314087e-21.
# Epoch 81/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1825 - accuracy: 0.9421 - val_loss: 0.1222 - val_accuracy: 0.9622
#
# Epoch 00081: val_accuracy did not improve from 0.96726
# Epoch 82/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1877 - accuracy: 0.9406 - val_loss: 0.1286 - val_accuracy: 0.9637
#
# Epoch 00082: val_accuracy did not improve from 0.96726
#
# Epoch 00082: ReduceLROnPlateau reducing learning rate to 1.667718253294226e-21.
# Epoch 83/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1898 - accuracy: 0.9379 - val_loss: 0.1288 - val_accuracy: 0.9631
#
# Epoch 00083: val_accuracy did not improve from 0.96726
# Epoch 84/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1956 - accuracy: 0.9397 - val_loss: 0.1358 - val_accuracy: 0.9613
#
# Epoch 00084: val_accuracy did not improve from 0.96726
#
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 5.003154881051713e-22.
# Epoch 85/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1872 - accuracy: 0.9415 - val_loss: 0.1261 - val_accuracy: 0.9661
#
# Epoch 00085: val_accuracy did not improve from 0.96726
# Epoch 86/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1886 - accuracy: 0.9396 - val_loss: 0.1300 - val_accuracy: 0.9613
#
# Epoch 00086: val_accuracy did not improve from 0.96726
#
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 1.500946434023255e-22.
# Epoch 87/100
# 420/420 [==============================] - 6s 14ms/step - loss: 0.1869 - accuracy: 0.9423 - val_loss: 0.1391 - val_accuracy: 0.9598
#
# Epoch 00087: val_accuracy did not improve from 0.96726
# Epoch 88/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1827 - accuracy: 0.9438 - val_loss: 0.1380 - val_accuracy: 0.9598
#
# Epoch 00088: val_accuracy did not improve from 0.96726
#
# Epoch 00088: ReduceLROnPlateau reducing learning rate to 4.5028393778004124e-23.
# Epoch 89/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1811 - accuracy: 0.9435 - val_loss: 0.1244 - val_accuracy: 0.9625
#
# Epoch 00089: val_accuracy did not improve from 0.96726
# Epoch 90/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1865 - accuracy: 0.9411 - val_loss: 0.1325 - val_accuracy: 0.9610
#
# Epoch 00090: val_accuracy did not improve from 0.96726
#
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 1.350851851205447e-23.
# Epoch 91/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1872 - accuracy: 0.9429 - val_loss: 0.1336 - val_accuracy: 0.9604
#
# Epoch 00091: val_accuracy did not improve from 0.96726
# Epoch 92/100
# 420/420 [==============================] - 6s 14ms/step - loss: 0.1801 - accuracy: 0.9428 - val_loss: 0.1319 - val_accuracy: 0.9601
#
# Epoch 00092: val_accuracy did not improve from 0.96726
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 4.05255564827965e-24.
# Epoch 93/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1850 - accuracy: 0.9400 - val_loss: 0.1303 - val_accuracy: 0.9646
#
# Epoch 00093: val_accuracy did not improve from 0.96726
# Epoch 94/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1820 - accuracy: 0.9451 - val_loss: 0.1262 - val_accuracy: 0.9625
#
# Epoch 00094: val_accuracy did not improve from 0.96726
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 1.2157666708180678e-24.
# Epoch 95/100
# 420/420 [==============================] - 7s 16ms/step - loss: 0.1819 - accuracy: 0.9431 - val_loss: 0.1340 - val_accuracy: 0.9601
#
# Epoch 00095: val_accuracy did not improve from 0.96726
# Epoch 96/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1819 - accuracy: 0.9437 - val_loss: 0.1287 - val_accuracy: 0.9604
#
# Epoch 00096: val_accuracy did not improve from 0.96726
#
# Epoch 00096: ReduceLROnPlateau reducing learning rate to 3.6473000716187714e-25.
# Epoch 97/100
# 420/420 [==============================] - 6s 14ms/step - loss: 0.1926 - accuracy: 0.9400 - val_loss: 0.1285 - val_accuracy: 0.9595
#
# Epoch 00097: val_accuracy did not improve from 0.96726
# Epoch 98/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1900 - accuracy: 0.9409 - val_loss: 0.1370 - val_accuracy: 0.9592
#
# Epoch 00098: val_accuracy did not improve from 0.96726
#
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 1.0941900362767734e-25.
# Epoch 99/100
# 420/420 [==============================] - 6s 15ms/step - loss: 0.1847 - accuracy: 0.9411 - val_loss: 0.1222 - val_accuracy: 0.9649
#
# Epoch 00099: val_accuracy did not improve from 0.96726
# Epoch 100/100
# 420/420 [==============================] - 6s 14ms/step - loss: 0.1816 - accuracy: 0.9426 - val_loss: 0.1255 - val_accuracy: 0.9649
#
# Epoch 00100: val_accuracy did not improve from 0.96726
#
# Epoch 00100: ReduceLROnPlateau reducing learning rate to 3.28257003487461e-26.

# %%
fig = plt.figure(figsize=(18, 9))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

fig = plt.figure(figsize=(18, 9))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
score = model.evaluate(x_test, y_test)
print('Test accuarcy: %0.2f%%' % (score[0] * 100))
# Out:
# 105/105 [==============================] - 0s 3ms/step - loss: 0.0823 - accuracy: 0.9821
# Test accuarcy: 8.23%

# %%
plt.imshow(x_test[20])
plt.show()

# %%
pred = model.predict(x_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       120
#            1       1.00      0.99      1.00       120
#            2       0.96      0.98      0.97       120
#            3       1.00      0.97      0.99       120
#            4       0.99      1.00      1.00       120
#            5       0.99      0.98      0.99       120
#            6       0.99      0.98      0.99       120
#            7       0.97      0.97      0.97       120
#            8       0.96      0.93      0.94       120
#            9       0.96      0.98      0.97       120
#           10       0.95      0.93      0.94       120
#           11       1.00      1.00      1.00       120
#           12       0.99      1.00      1.00       120
#           13       0.98      1.00      0.99       120
#           14       0.99      0.97      0.98       120
#           15       0.97      1.00      0.98       120
#           16       1.00      0.97      0.98       120
#           17       0.99      0.97      0.98       120
#           18       0.98      1.00      0.99       120
#           19       0.98      0.99      0.98       120
#           20       1.00      0.97      0.99       120
#           21       0.98      0.99      0.99       120
#           22       0.98      0.99      0.99       120
#           23       1.00      0.98      0.99       120
#           24       0.97      0.97      0.97       120
#           25       0.98      0.99      0.99       120
#           26       0.98      0.98      0.98       120
#           27       0.99      1.00      1.00       120
#
#     accuracy                           0.98      3360
#    macro avg       0.98      0.98      0.98      3360
# weighted avg       0.98      0.98      0.98      3360

# %%
from sklearn.metrics import confusion_matrix

fig,ax=plt.subplots(1,1,figsize=(28,25))
sns.heatmap(confusion_matrix(y_test_new,pred),ax=ax,xticklabels=arabic_characters,yticklabels=arabic_characters,annot=True,fmt=".1f",cmap="crest")


plt.show()
